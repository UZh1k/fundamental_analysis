# %%
import FundamentalAnalysis as fa
import pandas as pd

# %%
api_key = '891eb7484d76ff0dd412e8df2cdc3d74'

# %%
companies = fa.available_companies(api_key)

# %%
companies = pd.DataFrame(companies)
companies.reset_index(drop=True)
companies
# Out:
#                                                name   price  \
# symbol
# SPY                          SPDR S&P 500 ETF Trust  424.78
# CMCSA                           Comcast Corporation   45.35
# KMI                             Kinder Morgan, Inc.   17.38
# INTC                              Intel Corporation   44.58
# MU                          Micron Technology, Inc.   72.85
# ...                                             ...     ...
# 0P00000XI6.F    Naranja Standard &amp; Poors 500 PP   92.61
# 0P00000XI7.F          Naranja Renta Fija Europea PP   51.81
# WNNR                     Andretti Acquisition Corp.    9.97
# VCLN          Virtus Duff & Phelps Clean Energy ETF   22.18
# ACAB          Atlantic Coastal Acquisition Corp. II    9.88
#
#                                   exchange exchangeShortName   type
# symbol
# SPY           New York Stock Exchange Arca              AMEX    etf
# CMCSA                 Nasdaq Global Select            NASDAQ  stock
# KMI                New York Stock Exchange              NYSE  stock
# INTC                  Nasdaq Global Select            NASDAQ  stock
# MU                    Nasdaq Global Select            NASDAQ  stock
# ...                                    ...               ...    ...
# 0P00000XI6.F                     Frankfurt             XETRA   fund
# 0P00000XI7.F                     Frankfurt             XETRA   fund
# WNNR               New York Stock Exchange              NYSE  stock
# VCLN          New York Stock Exchange Arca              NYSE  stock
# ACAB                  NASDAQ Global Select            NASDAQ  stock
#
# [39287 rows x 5 columns]

# %%
quotes = fa.quote('MSFT', api_key)
quotes
# Out:
#                                                  0
# symbol                                        MSFT
# name                         Microsoft Corporation
# price                                       285.72
# changesPercentage                         3.356967
# change                                    9.279999
# dayLow                                     278.725
# dayHigh                                     285.73
# yearHigh                                    349.67
# yearLow                                     229.35
# marketCap                          2142005624832.0
# priceAvg50                                 301.066
# priceAvg200                              300.17664
# volume                                    21952605
# avgVolume                                 37451268
# exchange                                    NASDAQ
# open                                        280.35
# previousClose                               276.44
# eps                                          9.389
# pe                                       30.431356
# earningsAnnouncement  2022-04-25T10:59:00.000+0000
# sharesOutstanding                       7496869750
# timestamp                               1647371885

# %%
quotes.T
# Out:
#   symbol                   name   price changesPercentage    change   dayLow  \
# 0   MSFT  Microsoft Corporation  285.72          3.356967  9.279999  278.725
#
#   dayHigh yearHigh yearLow        marketCap  ...    volume avgVolume exchange  \
# 0  285.73   349.67  229.35  2142005624832.0  ...  21952605  37451268   NASDAQ
#
#      open previousClose    eps         pe          earningsAnnouncement  \
# 0  280.35        276.44  9.389  30.431356  2022-04-25T10:59:00.000+0000
#
#   sharesOutstanding   timestamp
# 0        7496869750  1647371885
#
# [1 rows x 22 columns]

# %%
tickers = ['AAPL', 'SNP', 'BTC-USD', 'UBI', 'ATVI']
df = fa.quote('MSFT', api_key).T
for ticker in tickers:
    print(ticker)
    quotes = fa.quote(ticker, api_key)
    df.append(quotes.T, ignore_index=True)
# Out:
# AAPL
# SNP
# BTC-USD
# UBI
# ATVI

# %%
tickers = ['MSFT', 'AAPL', 'SNP', 'UBI', 'ATVI']
df = pd.DataFrame()
for ticker in tickers:
    one_companie_df = fa.balance_sheet_statement(ticker, api_key, period="annual", limit=5).T
    one_companie_df['ticker'] = ticker
    df = df.append(one_companie_df)

cols = df.columns.tolist()[:-1]
cols.insert(0, 'ticker')
cols_to_remove = ['cik', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink']
for ctr in cols_to_remove:
    cols.remove(ctr)

df = df[cols]

writer = pd.ExcelWriter("fundamental_analysis_result.xlsx", engine = 'openpyxl')

df.to_excel(writer,
            sheet_name='balance_sheet')

# %%
df.dtypes
# Out:
# ticker                                     object
# reportedCurrency                           object
# calendarYear                               object
# cashAndCashEquivalents                     object
# shortTermInvestments                       object
# cashAndShortTermInvestments                object
# netReceivables                             object
# inventory                                  object
# otherCurrentAssets                         object
# totalCurrentAssets                         object
# propertyPlantEquipmentNet                  object
# goodwill                                   object
# intangibleAssets                           object
# goodwillAndIntangibleAssets                object
# longTermInvestments                        object
# taxAssets                                  object
# otherNonCurrentAssets                      object
# totalNonCurrentAssets                      object
# otherAssets                                object
# totalAssets                                object
# accountPayables                            object
# shortTermDebt                              object
# taxPayables                                object
# deferredRevenue                            object
# otherCurrentLiabilities                    object
# totalCurrentLiabilities                    object
# longTermDebt                               object
# deferredRevenueNonCurrent                  object
# deferredTaxLiabilitiesNonCurrent           object
# otherNonCurrentLiabilities                 object
# totalNonCurrentLiabilities                 object
# otherLiabilities                           object
# capitalLeaseObligations                    object
# totalLiabilities                           object
# preferredStock                             object
# commonStock                                object
# retainedEarnings                           object
# accumulatedOtherComprehensiveIncomeLoss    object
# othertotalStockholdersEquity               object
# totalStockholdersEquity                    object
# totalLiabilitiesAndStockholdersEquity      object
# minorityInterest                           object
# totalEquity                                object
# totalLiabilitiesAndTotalEquity             object
# totalInvestments                           object
# totalDebt                                  object
# netDebt                                    object
# dtype: object

# %%
fa.balance_sheet_statement('UBI.PA', api_key, period="annual", limit=5)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/FundamentalAnalysis/financial_statements.py:96, in balance_sheet_statement(ticker, api_key, period, as_reported, limit)
#      95 try:
# ---> 96     response = urlopen(URL)
#      97     data = json.loads(response.read().decode("utf-8"))
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File /usr/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 fa.balance_sheet_statement('UBI.PA', api_key, period="annual", limit=5)
#
# File ~/.local/lib/python3.10/site-packages/FundamentalAnalysis/financial_statements.py:99, in balance_sheet_statement(ticker, api_key, period, as_reported, limit)
#      97     data = json.loads(response.read().decode("utf-8"))
#      98 except HTTPError:
# ---> 99     raise ValueError("This endpoint is only for premium members. Please visit the subscription page to upgrade the "
#     100                      "plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing")
#     102 if 'Error Message' in data:
#     103     raise ValueError(data['Error Message'])
#
# ValueError: This endpoint is only for premium members. Please visit the subscription page to upgrade the plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing

# %%
tickers = ['MSFT', 'AAPL', 'SNP', 'UBI', 'ATVI']
df = pd.DataFrame()
for ticker in tickers:
    one_companie_df = fa.balance_sheet_statement(ticker, api_key, period="annual", limit=5).T
    one_companie_df['ticker'] = ticker
    df = df.append(one_companie_df)

cols = df.columns.tolist()[:-1]
cols.insert(0, 'ticker')
cols_to_remove = ['cik', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink']
for ctr in cols_to_remove:
    cols.remove(ctr)

df = df[cols]

writer = pd.ExcelWriter("fundamental_analysis_result.xlsx", engine = 'openpyxl')

df.to_excel(writer,
            sheet_name='balance_sheet')

# %%
df_cash_flow = pd.DataFrame()
for ticker in tickers:
    one_companie_df = fa.cash_flow_statement(ticker, api_key, period="annual", limit=5).T
    one_companie_df['ticker'] = ticker
    df_cash_flow = df_cash_flow.append(one_companie_df)

cols = df_cash_flow.columns.tolist()[:-1]
cols.insert(0, 'ticker')
cols_to_remove = ['cik', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink']
for ctr in cols_to_remove:
    cols.remove(ctr)
    
df_cash_flow = df_cash_flow[cols]
df_cash_flow.to_excel(writer,
                     sheet_name='cash_flow')

# %%
df_income_statement = pd.DataFrame()
for ticker in tickers:
    one_companie_df = fa.income_statement(ticker, api_key, period="annual", limit=5).T
    one_companie_df['ticker'] = ticker
    df_income_statement = df_income_statement.append(one_companie_df)

cols = df_income_statement.columns.tolist()[:-1]
cols.insert(0, 'ticker')
cols_to_remove = ['cik', 'fillingDate', 'acceptedDate', 'period', 'link', 'finalLink']
for ctr in cols_to_remove:
    cols.remove(ctr)
    
df_income_statement = df_income_statement[cols]
df_income_statement.to_excel(writer,
                             sheet_name='income_statement')

writer.save()
